# %%
import pandas as pd
from nltk.tokenize import word_tokenize
from collections import Counter
import nltk
nltk.download('punkt')

# Cargar el archivo CSV

df = pd.read_csv('../../data/hey_data.csv',encoding='latin1')

# Concatenar todos los tweets en un solo string
texto_completo = ' '.join(df['tweet'])

# Tokenizar el texto completo en palabras
palabras = word_tokenize(texto_completo)

# Contar la frecuencia de cada palabra
frecuencia_palabras = Counter(palabras)

# Imprimir el conteo de palabras más comunes
print("Conteo de palabras más comunes:")
for palabra, frecuencia in frecuencia_palabras.most_common():
    print(f"{palabra}: {frecuencia}")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\joaqu\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# Conteo de palabras más comunes:
# ,: 474
# de: 424
# .: 415
# la: 278
# !: 276
# que: 250
# y: 244
# a: 193
# el: 168
# en: 167
# Gracias: 165
# gracias: 164
# me: 163
# por: 156
# con: 120
# para: 99
# mi: 98
# es: 91
# ya: 89
# un: 82
# no: 77
# los: 76
# lo: 70
# una: 65
# Muchas: 61
# mÃ¡s: 55
# se: 50
# las: 49
# tarjeta: 48
# te: 46
# su: 43
# al: 42
# HeyBanco: 42
# si: 39
# como: 38
# muy: 37
# Hey: 37
# Ya: 36
# ?: 36
# :: 35
# mejor: 34
# cuenta: 32
# bien: 32
# les: 32
# Me: 31
# pero: 30
# %: 30
# sin: 30
# tengo: 29
# muchas: 28
# del: 27
# banco: 27
# ): 26
# tu: 26
# «: 25
# mucho: 24
# dÃ­as: 24
# dÃ­a: 24
# app: 24
# Hola: 24
# Yo: 23
# todo: 23
# esta: 23
# estÃ¡: 22
# problema: 21
# recomiendo: 20
# crÃ©dito: 20
# eso: 20
# ð: 19
# hey: 19
# he: 18
# o: 18
# @: 18
# buena: 18
# este: 18
# asÃ­: 17
# »: 17
# ...
